# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load CSV file
def load_data(file_path):
    try:
        df = pd.read_csv(file_path)
        print("Data loaded successfully!")
        return df
    except Exception as e:
        print(f"Error loading data: {e}")
        return None
# Out:
# Data loaded successfully!
#       SRNO       COMPANY        DATE  QUANTITY  PURCHASE PRICE  \
# 0      1.0     GUJGASLTD  16-08-2021      10.0          738.80
# 1      2.0    HAPPSTMNDS  16-08-2021       8.0         1394.00
# 2      3.0       MPHASIS  16-08-2021       5.0         2772.15
# 3      4.0         WIPRO  16-08-2021      20.0          615.25
# 4      5.0     GUJGASLTD  16-08-2021      10.0          749.95
# ..     ...           ...         ...       ...             ...
# 98    99.0   PIDILITEIND  22-09-2021       5.0         2421.95
# 99   100.0          SBIN  22-09-2021      50.0          439.85
# 100  101.0  MOULDTEKPACK  22-09-2021      10.0          559.00
# 101  102.0      YES BANK  22-09-2021     100.0           13.26
# 102  103.0          CDSL  22-09-2021      10.0         1274.50
#
#      PURCHASE VALUE  Latest Price   Profit/Loss  Percentage Change  \
# 0           7388.00    392.649994  -3461.500061         -46.853006
# ...

# %%
# Plot Profit and Loss
def plot_profit_loss(df):
    if df is None:
        print("No data to plot.")
        return

    # Check for required columns
    if 'DATE' not in df.columns or 'Profit/Loss' not in df.columns:
        print("CSV must contain 'DATE' and 'Profit/Loss' columns.")
        return

    # Convert Date to datetime
    df['DATE'] = pd.to_datetime(df['DATE'])

    # Plot data
    plt.figure(figsize=(12, 6))
    plt.plot(df['DATE'], df['Profit/Loss'], label='Profit/Loss', color='blue', marker='o')

    plt.xlabel('Date')
    plt.ylabel('Profit/Loss')
    plt.title('Profit and Loss Over Time')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Main Function
def main():
    file_path = "B:\HELLO\Investment-Analysis\Profit_Loss_Report.csv"
    df = load_data(file_path)
    plot_profit_loss(df)

if __name__ == "__main__":
    main()
# Out:
# Data loaded successfully!
# C:\Users\yashk\AppData\Local\Temp\ipykernel_10748\4100066839.py:13: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['DATE'] = pd.to_datetime(df['DATE'])
