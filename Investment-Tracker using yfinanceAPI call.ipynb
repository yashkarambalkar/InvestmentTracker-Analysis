# %%
import time
import datetime

# %%
import pandas as pd
import math 
stats = pd.read_csv(r'B:\HELLO\Investment-Analysis\YASHEXPR.csv', encoding='ISO-8859-1')

# %%
stats.head()
# Out:
#    SRNO     COMPANY        DATE  QUANTITY  PURCHASE PRICE  PURCHASE VALUE
# 0   1.0   GUJGASLTD  16-08-2021      10.0          738.80         7388.00
# 1   2.0  HAPPSTMNDS  16-08-2021       8.0         1394.00        11152.00
# 2   3.0     MPHASIS  16-08-2021       5.0         2772.15        13860.75
# 3   4.0       WIPRO  16-08-2021      20.0          615.25        12305.00
# 4   5.0   GUJGASLTD  16-08-2021      10.0          749.95         7499.50

# %%
cmpy = stats['COMPANY'].dropna().unique().tolist()
cmpy
# Out:
# ['GUJGASLTD',
#  'HAPPSTMNDS',
#  'MPHASIS',
#  'WIPRO',
#  'ASIANPAINTÿ',
#  'TATAELXSI',
#  'BALKRISIND',
#  'BAJAJ FINANCE',
#  'PIDILITEIND',
#  'SBIN',
#  'ICICI BANK',
#  'CDSL',
#  'AFFLE',
#  'COFORGE',
#  'DIVIS LAB',
#  'DIXON TECH',
#  'HERO MOTOCORP',
#  'GRINDWELL NOTRON',
#  'HDFCBANK',
#  'TATA MOTORS',
#  'YES BANK',
#  'HAVELLS',
#  'GAIL',
#  'PERSISTANT ',
#  'L&T TECHNOLOGY',
#  'LTI',
#  'TCS',
#  'INFOSYS',
#  'TECH MAHINDRA',
#  'JUPITERIND',
#  'TATA ELXSI',
#  'MOULDTEKPACK']

# %%
###HTTPError: HTTP Error 429: Too Many Requests
'''
ticker = 'INFY'
period1 = int(time.mktime(datetime.datetime(2000,12,1,23,59).timetuple()))
period2 = int(time.mktime(datetime.datetime.today().timetuple()))

interval = '1mo'
api_call = f'https://query1.finance.yahoo.com/v7/finance/download/{ticker}?period1={period1}&period2={period2}&interval={interval}&events=history&includeAdjustedClose=true'

dataF = pd.read_csv(api_call)
dataF.columns = ['Date','Open','High','Low','Close','Adj_Close','Volume']
dataF
'''
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[20], line 8
#       5 interval = '1mo'
#       6 api_call = f'https://query1.finance.yahoo.com/v7/finance/download/{ticker}?period1={period1}&period2={period2}&interval={interval}&events=history&includeAdjustedClose=true'
# ----> 8 dataF = pd.read_csv(api_call)
#       9 dataF.columns = ['Date','Open','High','Low','Close','Adj_Close','Volume']
#      10 dataF
#
# ...

# %%
# Function to safely format ticker symbols
def get_ticker(company):
    if isinstance(company, str):  # Ensure it's a string before applying operations
        return company.strip().replace(" ", "") + ".NS"  # Assuming NSE exchange
    return None  # Return None if the value is NaN

# Apply the function safely
stats['Ticker'] = stats['COMPANY'].apply(get_ticker)

# Drop rows where ticker is None (invalid company names)
stats = stats.dropna(subset=['Ticker'])

# Fetch latest prices using the corrected tickers
latest_prices = {}

for ticker in stats['Ticker'].unique():
    try:
        stock_data = yf.download(ticker, period="1d")
        if not stock_data.empty:
            latest_prices[ticker] = stock_data['Close'].iloc[-1]
    except Exception as e:
        latest_prices[ticker] = None

# Map latest prices to original dataframe
stats['Latest Price'] = stats['Ticker'].map(latest_prices)

# Calculate profit/loss
stats['Profit/Loss'] = (stats['Latest Price'] - stats['PURCHASE PRICE']) * stats['QUANTITY']
stats['Percentage Change'] = ((stats['Latest Price'] - stats['PURCHASE PRICE']) / stats['PURCHASE PRICE']) * 100

# Save to a new CSV
output_file = r'B:\HELLO\Investment-Analysis\Profit_Loss_Report.csv'
stats.to_csv(output_file, index=False)

print(f" Profit/Loss report saved as: {output_file}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ASIANPAINTŸ.NS']: YFPricesMissingError('possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BAJAJFINANCE.NS']: YFPricesMissingError('possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
#
# ...

# %%
# Function to safely format ticker symbols
def get_ticker(company):
    if isinstance(company, str):  # Ensure it's a string before applying operations
        return company.strip().replace(" ", "") + ".NS"  # Assuming NSE exchange
    return None  # Return None if the value is NaN

# Apply the function safely
stats['Ticker'] = stats['COMPANY'].apply(get_ticker)

# Drop rows where ticker is None (invalid company names)
stats = stats.dropna(subset=['Ticker'])

# Fetch latest prices using the corrected tickers
latest_prices = {}

for ticker in stats['Ticker'].unique():
    try:
        stock_data = yf.download(ticker, period="1d")
        if not stock_data.empty:
            latest_prices[ticker] = stock_data['Close'].iloc[-1].item()  # Extract scalar value
    except Exception as e:
        latest_prices[ticker] = None

# Map latest prices to original dataframe
stats['Latest Price'] = stats['Ticker'].map(latest_prices)

# Ensure profit/loss calculations also return only numeric values
stats['Profit/Loss'] = ((stats['Latest Price'] - stats['PURCHASE PRICE']) * stats['QUANTITY']).astype(float)
stats['Percentage Change'] = (((stats['Latest Price'] - stats['PURCHASE PRICE']) / stats['PURCHASE PRICE']) * 100).astype(float)

# Save to a new CSV
output_file = r'B:\HELLO\Investment-Analysis\Profit_Loss_Report.csv'
stats.to_csv(output_file, index=False)

print(f" Profit/Loss report saved as: {output_file}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ASIANPAINTŸ.NS']: YFPricesMissingError('possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BAJAJFINANCE.NS']: YFPricesMissingError('possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
#
# ...
